# %%
import pandas as pd

# %%
data = pd.read_csv("hijab_store.csv")

# %%
data
# Out:
#     id                        name          color     fabric         type  \
# 0    1         Classic Satin Hijab          Black      Satin        Plain
# 1    2       Premium Chiffon Hijab           Nude    Chiffon        Plain
# 2    3       Everyday Cotton Hijab     Dusty Pink     Cotton        Plain
# 3    4      Textured Crinkle Hijab           Grey     Cotton      Crinkle
# 4    5         Shimmer Satin Hijab  Emerald Green      Satin      Shimmer
# 5    6   Lightweight Chiffon Hijab         Maroon    Chiffon        Plain
# 6    7            Luxe Modal Hijab          Beige      Modal        Plain
# 7    8       Jersey Everyday Hijab      Navy Blue     Jersey        Plain
# 8    9         Premium Satin Hijab      Champagne      Satin        Plain
# 9   10        Crinkle Cotton Hijab          Olive     Cotton      Crinkle
# 10  11          Elegant Silk Hijab          Ivory       Silk        Plain
# 11  12         Matte Chiffon Hijab          Mauve    Chiffon        Plain
# ...
